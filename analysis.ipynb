# %%
import pandas as pd

btc = pd.read_csv(r"binance_project_data\BTCUSDT\BTCUSDT_4h_merged.csv")
eth = pd.read_csv(r"binance_project_data\ETHUSDT\ETHUSDT_4h_merged.csv")

print("BTC shape:", btc.shape)
print("ETH shape:", eth.shape)

print("\nBTC columns:")
print(btc.columns.tolist())

print("\nETH columns:")
print(eth.columns.tolist())

print("\nBTC head:")
display(btc.head())

print("\nETH head:")
display(eth.head())
# Out:
# BTC shape: (4867, 22)
# ETH shape: (4867, 22)
#
# BTC columns:
# ['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore', 'fundingRate', 'markPrice', 'return_1', 'future_return_1', 'hl_spread', 'co_return', 'volume_change', 'ma_5', 'ma_20', 'volatility_20']
#
# ETH columns:
# ['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore', 'fundingRate', 'markPrice', 'return_1', 'future_return_1', 'hl_spread', 'co_return', 'volume_change', 'ma_5', 'ma_20', 'volatility_20']
#
# BTC head:
#                    open_time      open      high       low     close  \
# 0  2024-01-01 00:00:00+00:00  42283.58  42775.00  42230.08  42330.49
# 1  2024-01-01 04:00:00+00:00  42330.50  42500.00  42180.77  42492.46
# ...
